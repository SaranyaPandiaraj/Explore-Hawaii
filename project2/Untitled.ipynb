# %%
import pandas as pd

# %%
tables = pd.read_csv("hawii_tourism.csv")
tables=pd.DataFrame(tables)
tables
# Out:
#                                                              Indicator  \
# Number_of_Visitors_by _air_and_cruiseship              State of Hawaii
# Length _of _Stay_ air _and_cruiseship                  State of Hawaii
# PPPD_spending_air_and_ cruise_ship                     State of Hawaii
# Number_of_Visitors_by _air                             State of Hawaii
# Length_of _Stay_by _air                                State of Hawaii
# Length_of _Stay_by _cruiseship                         State of Hawaii
# Number_of_Visitors_by _air                                 Maui County
# Length_of _Stay_by _air                                    Maui County
# PPPD_spending_air                                          Maui County
# Number_of_Visitors_by _air                 City and County of Honolulu
# Length _of_stay_by_air                     City and County of Honolulu
# PPPD_spending_air                          City and County of Honolulu
# ...

# %%
tables[4:]
# Out:
#                                                   Indicator       Area  \
# Length_of _Stay_by _air                     State of Hawaii       Days
# Length_of _Stay_by _cruiseship              State of Hawaii       Days
# Number_of_Visitors_by _air                      Maui County    Persons
# Length_of _Stay_by _air                         Maui County       Days
# PPPD_spending_air                               Maui County  Current $
# Number_of_Visitors_by _air      City and County of Honolulu    Persons
# Length _of_stay_by_air          City and County of Honolulu       Days
# PPPD_spending_air               City and County of Honolulu  Current $
# Number_of_Visitors_by _air                     Kauai County    Persons
# Length_of _Stay_by _air                        Kauai County       Days
# PPPD_spending_air                              Kauai County  Current $
#
#                                   Units  2010-01  2010-02  2010-03  2010-04  \
# ...

# %%
tables.columns
# Out:
# Index(['Indicator', 'Area', 'Units', '2010-01', '2010-02', '2010-03',
#        '2010-04', '2010-05', '2010-06', '2010-07',
#        ...
#        '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06',
#        '2019-07', '2019-08', '2019-09', '2019-10'],
#       dtype='object', length=121)
